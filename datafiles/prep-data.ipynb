# %% [markdown]
# # Helper Notebook to Prep Data Sets (.csv.gz)

# %%
from fsds.imports import *
# Out:
# fsds v0.4.9 loaded.
# <style  type="text/css" >
# ...

# %% [markdown]
# ## King County + Phase 2 Version

# %%
url ="https://raw.githubusercontent.com/learn-co-curriculum/dsc-phase-2-project/main/data/kc_house_data.csv"
df = pd.read_csv(url)
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.to_csv('king-county-housing-project-version.csv.gz',index=False,compression='gzip')

# %%
df = pd.read_csv('king-county-housing-project-version.csv.gz')
df['sqft_basement'].value_counts()
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
#           ...
# 248.0         1
# 2240.0        1
# 3480.0        1
# 225.0         1
# 588.0         1
# Name: sqft_basement, Length: 304, dtype: int64

# %%
## kaggle version https://www.kaggle.com/harlfoxem/housesalesprediction
df2 = pd.read_csv("~/Downloads/kc_house_data.csv")
df2['sqft_basement'].value_counts()
# Out:
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df2.to_csv('king-county-housing-kaggle-version.csv.gz',compression='gzip',index=False)

# %%
pd.read_csv('king-county-housing-kaggle-version.csv.gz')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ## Titanic Dataset

# %%
#https://python.plainenglish.io/how-to-use-the-kaggle-api-in-python-4d4c812c39c7
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('heptapod/titanic')

# %%
from zipfile import ZipFile
with ZipFile('titanic.zip') as file:
    file.extractall('./')

# %%
df = pd.read_csv('train_and_test2.csv')
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
df.to_csv('./titanic.csv.gz',compression='gzip',index=False)

# %%
url ="https://raw.githubusercontent.com/jirvingphd/fsds/master/datafiles/titanic.csv.gz"
pd.read_csv(url)
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %% [markdown]
# # Previous data

# %%
import os,glob
os.listdir()
# Out:
# ['.DS_Store',
#  'vgsales.csv',
#  'world-happiness-report',
#  'prep-data.ipynb',
#  'hotel_bookings.csv.gz']

# %%
# df = pd.read_csv('hotel_bookings.csv')
# df.to_csv('hotel_bookings.csv.gz',compression='gzip',index=False)

# %%
# files = glob.glob('world-happiness-report/*')
# files

# %%
# data = {}
# for file in files:
#     name = file.split('/')[-1].replace('.csv','')
#     temp = pd.read_csv(file)
    
#     temp['year']=name
#     data[name] = temp.copy()
#     print(name)
#     display(data[name].shape)#).style.set_caption(name))

# %%
# df= pd.concat([data['2019'],data['2018']])
# df

# %% [markdown]
# - Bridging the old vs new files

# %%
# df.columns

# %%
# data['2017'].columns

# %%
# [c for c in df.columns if c not in data['2017'].columns]
